# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunkasana-26/Combo-finder/blob/main/Combo_finder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find all the list of products whose sum-of-price is between 290 and 310.
#
# ProductList = {p1:10, p2:15, p3:20, p4:25, p5:30, p6:35, p7:50}

# %%
import random as r

# %%
productList =  {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50,}
UB = 310
LB = 290
ResultList = set()
iterations = 1000

# %%
setsize = r.randint(2, len(productList)-1)
print("Number of product", setsize)
combolist = r.sample(list(productList.keys()),setsize)
print("combolist : ", combolist)
combosum = sum([productList[i] for i in combolist])
print("sum of product" , combosum)
# Out:
# Number of product 4
# combolist :  ['p5', 'p4', 'p1', 'p2']
# sum of product 80

# %%
Resultlist = set()
for i in range(iterations):
  setsize = r.randint(2, len(productList)-1)
  print("Number of product", setsize)
  combolist = r.sample(list(productList.keys()),setsize)
  combolist.sort()
  print("combolist : ", combolist)
  combosum = sum([productList[i] for i in combolist])
  print("sum of product" , combosum)
  if combosum>=LB and combosum<=UB:
    Resultlist.add(tuple(combolist))
for r in ResultList:
	print (r)
print ("\nTotal Sets: ", len(ResultList), "\n")
# Out:
# Number of product 5
# combolist :  ['p1', 'p3', 'p5', 'p6', 'p7']
# sum of product 145
# Number of product 6
# combolist :  ['p1', 'p3', 'p4', 'p5', 'p6', 'p7']
# sum of product 170
# Number of product 6
# combolist :  ['p1', 'p2', 'p3', 'p4', 'p5', 'p6']
# sum of product 135
# Number of product 6
# combolist :  ['p1', 'p2', 'p3', 'p4', 'p5', 'p7']
# sum of product 150
# Number of product 3
# combolist :  ['p4', 'p6', 'p7']
# sum of product 110
# Number of product 4
# combolist :  ['p1', 'p2', 'p3', 'p5']
# sum of product 75
# Number of product 5
# combolist :  ['p1', 'p2', 'p3', 'p5', 'p7']
# sum of product 125
# Number of product 4
# combolist :  ['p1', 'p2', 'p4', 'p6']
# sum of product 85
# Number of product 5
# combolist :  ['p1', 'p2', 'p4', 'p6', 'p7']
# sum of product 135
# Number of product 6
# combolist :  ['p1', 'p2', 'p3', 'p4', 'p5', 'p7']
# sum of product 150
# Number of product 3
# combolist :  ['p4', 'p6', 'p7']
# sum of product 110
# Number of product 4
# ...
